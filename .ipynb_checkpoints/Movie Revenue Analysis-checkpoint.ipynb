# %% [markdown]
# # Top Earners in Movie Industry
#
# ## Table of Contents
#
# <ul>
#     <li><a href="#intro">Introduction</a></li>
#     <li><a href="#eda">Exploratory Data Analysis</a></li>
#     <li><a href="#conclusion">Conclusion</a></li>
# </ul>

# %% [markdown]
# <a id="#intro"></a>
# ## Introduction
#
# > This analysis project is to be done using the imdb movie data. When the analysis is completed, you should be able to find the top 5 highest grossing directors, the top 5 highest grossing movie genres of all time, comparing the revenue of the highest grossing movies and which companies released the most movies.
#
# > There are 10 columns that will not be needed for the analysis. Use pandas to drop these columns. HINT: Only the columns pertaining to revenue will be needed.
#
# > To get you started, I've already placed the needed code for getting the packages and datafile that you will be using for the project.

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('imdb-movies.csv')

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...  \
# 0              The park is open.  ...
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# ### Drop columns without neccesary information and remove all records with no financial information -- Pay close attention to things that don't tell you anything regarding financial data

# %%
df.drop(['id', 'imdb_id', 'cast', 'homepage', 'tagline', 'keywords', 'overview', 'runtime'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['popularity', 'budget', 'revenue', 'original_title', 'director',
#        'genres', 'production_companies', 'release_date', 'vote_count',
#        'vote_average', 'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %%
df.head()
# Out:
#    popularity     budget     revenue                original_title  \
# 0   32.985763  150000000  1513528810                Jurassic World
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
#
#            director                                     genres  \
# 0   Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 1     George Miller  Action|Adventure|Science Fiction|Thriller
# 2  Robert Schwentke         Adventure|Science Fiction|Thriller
# 3       J.J. Abrams   Action|Adventure|Science Fiction|Fantasy
# 4         James Wan                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15        5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15        2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09

# %%
df.drop(['release_date','vote_count', 'vote_average', 'popularity'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                10866 non-null  int64
#  1   revenue               10866 non-null  int64
#  2   original_title        10866 non-null  object
#  3   director              10822 non-null  object
#  4   genres                10843 non-null  object
#  5   production_companies  9836 non-null   object
#  6   release_year          10866 non-null  int64
#  7   budget_adj            10866 non-null  float64
#  8   revenue_adj           10866 non-null  float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 764.1+ KB

# %% [markdown]
# ### Data Cleaning

# %%
df.isna().sum()
# Out:
# budget                     0
# revenue                    0
# original_title             0
# director                  44
# genres                    23
# production_companies    1030
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# budget                     0
# revenue                    0
# original_title             0
# director                  44
# genres                    23
# production_companies    1030
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
# Delete all records with null, or empty values
df[df.isna().any(axis=1)]
# Out:
#        budget  revenue                      original_title  \
# 228         0        0                   Racing Extinction
# 259         0        0                 Crown for Christmas
# 295         0        0               12 Gifts of Christmas
# 298         0        0         The Girl in the Photographs
# 328         0        0                        Advantageous
# ...       ...      ...                                 ...
# 10804       0        0                           Interiors
# 10806       0        0                     Gates of Heaven
# 10816       0        0    The Rutles: All You Need Is Cash
# 10842       0        0  Winnie the Pooh and the Honey Tree
# 10853       0        0                               Alfie
#
#                   director                        genres production_companies  \
# 228         Louie Psihoyos         Adventure|Documentary                  NaN
# 259              Alex Zamm                      TV Movie                  NaN
# 295         Peter Sullivan               Family|TV Movie                  NaN
# 298             Nick Simon         Crime|Horror|Thriller                  NaN
# 328         Jennifer Phang  Science Fiction|Drama|Family                  NaN
# ...                    ...                           ...                  ...
# 10804          Woody Allen                         Drama                  NaN
# 10806         Errol Morris                   Documentary                  NaN
# 10816  Eric Idle|Gary Weis                        Comedy                  NaN
# 10842  Wolfgang Reitherman              Animation|Family                  NaN
# 10853        Lewis Gilbert          Comedy|Drama|Romance                  NaN
#
#        release_year  budget_adj  revenue_adj
# 228            2015         0.0          0.0
# 259            2015         0.0          0.0
# 295            2015         0.0          0.0
# 298            2015         0.0          0.0
# 328            2015         0.0          0.0
# ...             ...         ...          ...
# 10804          1978         0.0          0.0
# 10806          1978         0.0          0.0
# 10816          1978         0.0          0.0
# 10842          1966         0.0          0.0
# 10853          1966         0.0          0.0
#
# [1059 rows x 9 columns]

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# budget                  0
# revenue                 0
# original_title          0
# director                0
# genres                  0
# production_companies    0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# budget                  0
# revenue                 0
# original_title          0
# director                0
# genres                  0
# production_companies    0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %% [markdown]
# #### Here's a helpful hint from my own analysis when I ran this the first time. This may help shed light on what your data set should look like.
#
# #### If I created one record for each the `production_companies` a movie was release under and one record each for `genres`<br>and tried to run calculations, it wouldn't work because for many records, the amount of `production_companies`<br>and `genres` aren't the same, so I'll create 2 dataframes; one w/o a `production_companies` column and one w/o a `genres` columns

# %%
df.to_csv('imdb_genre.csv', index=False)
df.to_csv('imdb_company.csv', index=False)

# %%
df_genre = pd.read_csv('imdb_genre.csv')

# %%
df_company = pd.read_csv('imdb_company.csv')

# %%
df_genre.drop('production_companies', axis=1, inplace=True)

# %%
df_company.drop('genres', axis=1, inplace=True)

# %%
df_genre.head()
# Out:
#       budget     revenue                original_title          director  \
# 0  150000000  1513528810                Jurassic World   Colin Trevorrow
# 1  150000000   378436354            Mad Max: Fury Road     George Miller
# 2  110000000   295238201                     Insurgent  Robert Schwentke
# 3  200000000  2068178225  Star Wars: The Force Awakens       J.J. Abrams
# 4  190000000  1506249360                     Furious 7         James Wan
#
#                                       genres  release_year    budget_adj  \
# 0  Action|Adventure|Science Fiction|Thriller          2015  1.379999e+08
# 1  Action|Adventure|Science Fiction|Thriller          2015  1.379999e+08
# 2         Adventure|Science Fiction|Thriller          2015  1.012000e+08
# 3   Action|Adventure|Science Fiction|Fantasy          2015  1.839999e+08
# 4                      Action|Crime|Thriller          2015  1.747999e+08
#
#     revenue_adj
# 0  1.392446e+09
# 1  3.481613e+08
# 2  2.716190e+08
# 3  1.902723e+09
# 4  1.385749e+09

# %%
df_company.head()
# Out:
#       budget     revenue                original_title          director  \
# 0  150000000  1513528810                Jurassic World   Colin Trevorrow
# 1  150000000   378436354            Mad Max: Fury Road     George Miller
# 2  110000000   295238201                     Insurgent  Robert Schwentke
# 3  200000000  2068178225  Star Wars: The Force Awakens       J.J. Abrams
# 4  190000000  1506249360                     Furious 7         James Wan
#
#                                 production_companies  release_year  \
# 0  Universal Studios|Amblin Entertainment|Legenda...          2015
# 1  Village Roadshow Pictures|Kennedy Miller Produ...          2015
# 2  Summit Entertainment|Mandeville Films|Red Wago...          2015
# 3          Lucasfilm|Truenorth Productions|Bad Robot          2015
# 4  Universal Pictures|Original Film|Media Rights ...          2015
#
#      budget_adj   revenue_adj
# 0  1.379999e+08  1.392446e+09
# 1  1.379999e+08  3.481613e+08
# 2  1.012000e+08  2.716190e+08
# 3  1.839999e+08  1.902723e+09
# 4  1.747999e+08  1.385749e+09

# %%
df_genre.tail()
# Out:
#       budget  revenue            original_title            director  \
# 9802       0        0        The Endless Summer         Bruce Brown
# 9803       0        0                Grand Prix  John Frankenheimer
# 9804       0        0       Beregis Avtomobilya      Eldar Ryazanov
# 9805       0        0    What's Up, Tiger Lily?         Woody Allen
# 9806   19000        0  Manos: The Hands of Fate    Harold P. Warren
#
#                       genres  release_year     budget_adj  revenue_adj
# 9802             Documentary          1966       0.000000          0.0
# 9803  Action|Adventure|Drama          1966       0.000000          0.0
# 9804          Mystery|Comedy          1966       0.000000          0.0
# 9805           Action|Comedy          1966       0.000000          0.0
# 9806                  Horror          1966  127642.279154          0.0

# %%
multi_genre = df_genre[df_genre.genres.str.contains('|', regex=False)]

# %%
multi_genre.genres.count()
# Out:
# 7833

# %%
g1 = multi_genre.copy()
g2 = multi_genre.copy()


while multi_genre.genres.count() > 0:
    g1['genres'] = g1['genres'].apply(lambda x:x.split('|')[0])
    g2['genres'] = g2['genres'].apply(lambda x:'|'.join(x.split('|')[1:]))
    
    df_genre.drop(multi_genre.index, inplace=True)
    df_genre = df_genre.append(g1.append(g2), ignore_index=True)
    
    multi_genre = df_genre[df_genre.genres.str.contains('|', regex=False)]

df_genre[df_genre.genres.str.contains('|', regex=False)]
# Out:
# Empty DataFrame
# Columns: [budget, revenue, original_title, director, genres, release_year, budget_adj, revenue_adj]
# Index: []

# %%
df_genre
# Out:
#           budget    revenue                                    original_title  \
# 0      150000000  682330139                Mission: Impossible - Rogue Nation
# 1       68000000  215863606                                             Ted 2
# 2       35000000  194564672                                        The Intern
# 3       20000000   36606743                                             Burnt
# 4       15000000   64191523                                   The Danish Girl
# ...          ...        ...                                               ...
# 57556          0          0  The Russians Are Coming, The Russians Are Coming
# 57557          0          0                                           Seconds
# 57558          0          0                                        Grand Prix
# 57559          0          0                               Beregis Avtomobilya
# 57560          0          0                            What's Up, Tiger Lily?
#
#                     director  genres  release_year    budget_adj   revenue_adj
# 0      Christopher McQuarrie  Action          2015  1.379999e+08  6.277435e+08
# 1            Seth MacFarlane  Comedy          2015  6.255997e+07  1.985944e+08
# 2               Nancy Meyers  Comedy          2015  3.219999e+07  1.789994e+08
# 3                 John Wells   Drama          2015  1.839999e+07  3.367819e+07
# 4                 Tom Hooper   Drama          2015  1.379999e+07  5.905618e+07
# ...                      ...     ...           ...           ...           ...
# 57556         Norman Jewison                  1966  0.000000e+00  0.000000e+00
# 57557     John Frankenheimer                  1966  0.000000e+00  0.000000e+00
# 57558     John Frankenheimer                  1966  0.000000e+00  0.000000e+00
# 57559         Eldar Ryazanov                  1966  0.000000e+00  0.000000e+00
# 57560            Woody Allen                  1966  0.000000e+00  0.000000e+00
#
# [57561 rows x 8 columns]

# %%
df_company
# Out:
#          budget     revenue                original_title            director  \
# 0     150000000  1513528810                Jurassic World     Colin Trevorrow
# 1     150000000   378436354            Mad Max: Fury Road       George Miller
# 2     110000000   295238201                     Insurgent    Robert Schwentke
# 3     200000000  2068178225  Star Wars: The Force Awakens         J.J. Abrams
# 4     190000000  1506249360                     Furious 7           James Wan
# ...         ...         ...                           ...                 ...
# 9802          0           0            The Endless Summer         Bruce Brown
# 9803          0           0                    Grand Prix  John Frankenheimer
# 9804          0           0           Beregis Avtomobilya      Eldar Ryazanov
# 9805          0           0        What's Up, Tiger Lily?         Woody Allen
# 9806      19000           0      Manos: The Hands of Fate    Harold P. Warren
#
#                                    production_companies  release_year  \
# 0     Universal Studios|Amblin Entertainment|Legenda...          2015
# 1     Village Roadshow Pictures|Kennedy Miller Produ...          2015
# 2     Summit Entertainment|Mandeville Films|Red Wago...          2015
# 3             Lucasfilm|Truenorth Productions|Bad Robot          2015
# 4     Universal Pictures|Original Film|Media Rights ...          2015
# ...                                                 ...           ...
# 9802                                  Bruce Brown Films          1966
# 9803  Cherokee Productions|Joel Productions|Douglas ...          1966
# 9804                                            Mosfilm          1966
# 9805                            Benedict Pictures Corp.          1966
# 9806                                          Norm-Iris          1966
#
#         budget_adj   revenue_adj
# 0     1.379999e+08  1.392446e+09
# 1     1.379999e+08  3.481613e+08
# 2     1.012000e+08  2.716190e+08
# 3     1.839999e+08  1.902723e+09
# 4     1.747999e+08  1.385749e+09
# ...            ...           ...
# 9802  0.000000e+00  0.000000e+00
# 9803  0.000000e+00  0.000000e+00
# 9804  0.000000e+00  0.000000e+00
# 9805  0.000000e+00  0.000000e+00
# 9806  1.276423e+05  0.000000e+00
#
# [9807 rows x 8 columns]

# %%
# again for companies:
multi_company = df_company[df_company.production_companies.str.contains('|', regex=False)]
multi_company.production_companies.count()
# Out:
# 6392

# %%
c1 = multi_company.copy()
c2 = multi_company.copy()


while multi_company.production_companies.count() > 0:
    c1['production_companies'] = c1['production_companies'].apply(lambda x:x.split('|')[0])
    c2['production_companies'] = c2['production_companies'].apply(lambda x:'|'.join(x.split('|')[1:]))
    
    df_company.drop(multi_company.index, inplace=True)
    df_company = df_company.append(c1.append(c2), ignore_index=True)
    
    multi_company = df_company[df_company.production_companies.str.contains('|', regex=False)]

df_company[df_company.production_companies.str.contains('|', regex=False)]
# Out:
# Empty DataFrame
# Columns: [budget, revenue, original_title, director, production_companies, release_year, budget_adj, revenue_adj]
# Index: []

# %%
df_company = df_company[df_company['production_companies'] != '']

# %%
df_genre = df_genre[df_genre['genres'] != '']

# %%
df_genre
# Out:
#           budget    revenue                      original_title  \
# 0      150000000  682330139  Mission: Impossible - Rogue Nation
# 1       68000000  215863606                               Ted 2
# 2       35000000  194564672                          The Intern
# 3       20000000   36606743                               Burnt
# 4       15000000   64191523                     The Danish Girl
# ...          ...        ...                                 ...
# 57531    1377800          0                              Batman
# 57539   12000000   20000000                    The Sand Pebbles
# 57544          0          0                            Khartoum
# 57550          0          0                              Harper
# 57551          0          0                           Born Free
#
#                            director   genres  release_year    budget_adj  \
# 0             Christopher McQuarrie   Action          2015  1.379999e+08
# 1                   Seth MacFarlane   Comedy          2015  6.255997e+07
# 2                      Nancy Meyers   Comedy          2015  3.219999e+07
# 3                        John Wells    Drama          2015  1.839999e+07
# 4                        Tom Hooper    Drama          2015  1.379999e+07
# ...                             ...      ...           ...           ...
# 57531           Leslie H. Martinson    Crime          1966  9.256081e+06
# 57539                   Robert Wise  Romance          1966  8.061618e+07
# 57544  Basil Dearden|Eliot Elisofon   Action          1966  0.000000e+00
# 57550                   Jack Smight  Mystery          1966  0.000000e+00
# 57551                    James Hill  Foreign          1966  0.000000e+00
#
#         revenue_adj
# 0      6.277435e+08
# 1      1.985944e+08
# 2      1.789994e+08
# 3      3.367819e+07
# 4      5.905618e+07
# ...             ...
# 57531  0.000000e+00
# 57539  1.343603e+08
# 57544  0.000000e+00
# 57550  0.000000e+00
# 57551  0.000000e+00
#
# [41139 rows x 8 columns]

# %%
df_company
# Out:
#           budget    revenue                  original_title  \
# 0      130000000  518602163                         Ant-Man
# 1       12000000   85512300                     Paper Towns
# 2              0      45895                Beyond the Reach
# 3              0          0          Mythica: The Darkspore
# 4              0          0  Me and Earl and the Dying Girl
# ...          ...        ...                             ...
# 47261   42000000   20844907               Super Mario Bros.
# 47273   20000000  153698625                      Free Willy
# 47299   25000000          6        The House of the Spirits
# 47398   24500000   17218023                     The Mission
# 47423   15000000          0       The Clan of the Cave Bear
#
#                           director              production_companies  \
# 0                      Peyton Reed                    Marvel Studios
# 1                    Jake Schreier                 Fox 2000 Pictures
# 2          Jean-Baptiste LÃ©onetti                     Furthur Films
# 3                    Anne K. Black          Arrowstorm Entertainment
# 4              Alfonso Gomez-Rejon                 Indian Paintbrush
# ...                            ...                               ...
# 47261  Annabel Jankel|Rocky Morton                          Nintendo
# 47273                 Simon Wincer  Donner/Shuler-Donner Productions
# 47299                 Bille August              Neue Constantin Film
# 47398                Roland JoffÃ©        Kingsmere Productions Ltd.
# 47423              Michael Chapman                 The Jozak Company
#
#        release_year    budget_adj   revenue_adj
# 0              2015  1.195999e+08  4.771138e+08
# 1              2015  1.104000e+07  7.867128e+07
# 2              2015  0.000000e+00  4.222338e+04
# 3              2015  0.000000e+00  0.000000e+00
# 4              2015  0.000000e+00  0.000000e+00
# ...             ...           ...           ...
# 47261          1993  6.339774e+07  3.146476e+07
# 47273          1993  3.018940e+07  2.320035e+08
# 47299          1993  3.773675e+07  9.056820e+00
# 47398          1986  4.874046e+07  3.425365e+07
# 47423          1986  2.984110e+07  0.000000e+00
#
# [35375 rows x 8 columns]

# %% [markdown]
# <a id="eda"></a>
# ## Exploratory Data Analysis
#
# > Use Matplotlib to display your data analysis

# %% [markdown]
# ### Which production companies released the most movies in the last 10 years? Display the top 5 production companies.

# %%
#records stop in 2015, so I am going to look at 2006 to 2015

# %%
df_company06_15 = df_company.query('release_year > 2005').copy()

# %%
df_company06_15.production_companies.value_counts()
# Out:
# Universal Pictures              504
# Columbia Pictures               372
# Paramount Pictures              338
# Walt Disney Pictures            262
# New Line Cinema                 236
#                                ...
# Mark Gordon Productions           1
# Sonet Film AB                     1
# Quite Quick Productions           1
# Major International Pictures      1
# Anacol Productions Inc.           1
# Name: production_companies, Length: 3910, dtype: int64

# %%
release_count = df_company06_15.production_companies.value_counts().index
release_count
# Out:
# Index(['Universal Pictures', 'Columbia Pictures', 'Paramount Pictures',
#        'Walt Disney Pictures', 'New Line Cinema',
#        'Twentieth Century Fox Film Corporation', 'BBC Films',
#        'Summit Entertainment', 'DC Comics', 'Village Roadshow Pictures',
#        ...
#        'Suresh Productions', 'Antidote Films', 'Matchbox Pictures Inc.',
#        'Red Box Films', 'Red & Black Films', 'Mark Gordon Productions',
#        'Sonet Film AB', 'Quite Quick Productions',
#        'Major International Pictures', 'Anacol Productions Inc.'],
#       dtype='object', length=3910)

# %%
df_company_top5 = pd.DataFrame()

# %%
for company in release_count[:5]:
    df_company_top5 = df_company_top5.append(df_company06_15.query('production_companies == @company'))
df_company_top5
# Out:
#           budget    revenue                            original_title  \
# 5              0          0        The Scorpion King: The Lost Throne
# 413     40000000   28169671  Cirque du Freak: The Vampire's Assistant
# 508     42000000          0                                    BrÃ¼no
# 973     45000000  160078586                     Johnny English Reborn
# 1008           0          0           Beethoven's Christmas Adventure
# ...          ...        ...                                       ...
# 39275  180000000  372234864                        The Golden Compass
# 39277          0   39000000                                  Fracture
# 39296   39000000   26820641                              Shoot 'Em Up
# 39402          0   27297451                            The Last Mimzy
# 39405   45000000    4607608               Love in the Time of Cholera
#
#              director production_companies  release_year    budget_adj  \
# 5        Mike Elliott   Universal Pictures          2015  0.000000e+00
# 413        Paul Weitz   Universal Pictures          2009  4.065602e+07
# 508     Larry Charles   Universal Pictures          2009  4.268882e+07
# 973     Oliver Parker   Universal Pictures          2011  4.362291e+07
# 1008       John Putch   Universal Pictures          2011  0.000000e+00
# ...               ...                  ...           ...           ...
# 39275     Chris Weitz      New Line Cinema          2007  1.893003e+08
# 39277  Gregory Hoblit      New Line Cinema          2007  0.000000e+00
# 39296   Michael Davis      New Line Cinema          2007  4.101507e+07
# 39402    Robert Shaye      New Line Cinema          2007  0.000000e+00
# 39405     Mike Newell      New Line Cinema          2007  4.732509e+07
#
#         revenue_adj
# 5      0.000000e+00
# 413    2.863167e+07
# 508    0.000000e+00
# 973    1.551799e+08
# 1008   0.000000e+00
# ...             ...
# 39275  3.914677e+08
# 39277  4.101507e+07
# 39296  2.820643e+07
# 39402  2.870787e+07
# 39405  4.845677e+06
#
# [1712 rows x 8 columns]

# %%
df_company_top5.production_companies.hist(figsize=(15,10));
plt.title('Top Production Companies by Releases from 2006-2015');
plt.xlabel('Company');
plt.ylabel('Releases');

# %% [markdown]
# ### What 5 movie genres grossed the highest all-time?

# %%
df_genre.groupby(['genres']).revenue.sum().nlargest(5)
# Out:
# genres
# Action       401958655011
# Adventure    313022024985
# Comedy       230990378289
# Drama        224975762718
# Thriller     119764868534
# Name: revenue, dtype: int64

# %% [markdown]
# ### Who are the top 5 grossing directors?

# %%
df.groupby(['director']).revenue.sum().nlargest(5)
# Out:
# director
# Steven Spielberg     9018563772
# Peter Jackson        6523244659
# James Cameron        5841894863
# Michael Bay          4917208171
# Christopher Nolan    4167548502
# Name: revenue, dtype: int64

# %% [markdown]
# ### Compare the revenue of the highest grossing movies of all time.

# %%
df_top30 = df.nlargest(30,'revenue')

# %%
df_top30
# Out:
#          budget     revenue                                 original_title  \
# 1386  237000000  2781505847                                         Avatar
# 3     200000000  2068178225                   Star Wars: The Force Awakens
# 5231  200000000  1845034188                                        Titanic
# 4361  220000000  1519557910                                   The Avengers
# 0     150000000  1513528810                                 Jurassic World
# 4     190000000  1506249360                                      Furious 7
# 14    280000000  1405035767                        Avengers: Age of Ultron
# 3374  125000000  1327817822   Harry Potter and the Deathly Hallows: Part 2
# 5422  150000000  1274219009                                         Frozen
# 5425  200000000  1215439994                                     Iron Man 3
# 8      74000000  1156730962                                        Minions
# 3522  195000000  1123746996                 Transformers: Dark of the Moon
# 4949   94000000  1118888979  The Lord of the Rings: The Return of the King
# 4365  200000000  1108561013                                        Skyfall
# 8094   22000000  1106279658                                        The Net
# 4363  250000000  1081041287                          The Dark Knight Rises
# 6555  200000000  1065659812     Pirates of the Caribbean: Dead Man's Chest
# 1930  200000000  1063171911                                    Toy Story 3
# 1921  200000000  1025467110                            Alice in Wonderland
# 3375  380000000  1021683000    Pirates of the Caribbean: On Stranger Tides
# 4367  250000000  1017003568              The Hobbit: An Unexpected Journey
# 2875  185000000  1001921825                                The Dark Knight
# 2634  125000000   976475550       Harry Potter and the Philosopher's Stone
# 5434   76000000   970761885                                Despicable Me 2
# 7387  300000000   961000000       Pirates of the Caribbean: At World's End
# 5431  250000000   958400000            The Hobbit: The Desolation of Smaug
# 634   250000000   955119788      The Hobbit: The Battle of the Five Armies
# 1923  250000000   954305868   Harry Potter and the Deathly Hallows: Part 1
# 7388  150000000   938212738      Harry Potter and the Order of the Phoenix
# 1389  250000000   933959197         Harry Potter and the Half-Blood Prince
#
#                         director                                     genres  \
# 1386               James Cameron   Action|Adventure|Fantasy|Science Fiction
# 3                    J.J. Abrams   Action|Adventure|Science Fiction|Fantasy
# 5231               James Cameron                     Drama|Romance|Thriller
# 4361                 Joss Whedon           Science Fiction|Action|Adventure
# 0                Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 4                      James Wan                      Action|Crime|Thriller
# 14                   Joss Whedon           Action|Adventure|Science Fiction
# 3374                 David Yates                   Adventure|Family|Fantasy
# 5422     Chris Buck|Jennifer Lee                 Animation|Adventure|Family
# 5425                 Shane Black           Action|Adventure|Science Fiction
# 8       Kyle Balda|Pierre Coffin          Family|Animation|Adventure|Comedy
# 3522                 Michael Bay           Action|Science Fiction|Adventure
# 4949               Peter Jackson                   Adventure|Fantasy|Action
# 4365                  Sam Mendes                  Action|Adventure|Thriller
# 8094               Irwin Winkler        Crime|Drama|Mystery|Thriller|Action
# 4363           Christopher Nolan                Action|Crime|Drama|Thriller
# 6555              Gore Verbinski                   Adventure|Fantasy|Action
# 1930                 Lee Unkrich                    Animation|Family|Comedy
# 1921                  Tim Burton                   Family|Fantasy|Adventure
# 3375                Rob Marshall                   Adventure|Action|Fantasy
# 4367               Peter Jackson                   Adventure|Fantasy|Action
# 2875           Christopher Nolan                Drama|Action|Crime|Thriller
# 2634              Chris Columbus                   Adventure|Fantasy|Family
# 5434  Pierre Coffin|Chris Renaud                    Animation|Comedy|Family
# 7387              Gore Verbinski                   Adventure|Fantasy|Action
# 5431               Peter Jackson                          Adventure|Fantasy
# 634                Peter Jackson                          Adventure|Fantasy
# 1923                 David Yates                   Adventure|Fantasy|Family
# 7388                 David Yates           Adventure|Fantasy|Family|Mystery
# 1389                 David Yates                   Adventure|Fantasy|Family
#
#                                    production_companies  release_year  \
# 1386  Ingenious Film Partners|Twentieth Century Fox ...          2009
# 3             Lucasfilm|Truenorth Productions|Bad Robot          2015
# 5231  Paramount Pictures|Twentieth Century Fox Film ...          1997
# 4361                                     Marvel Studios          2012
# 0     Universal Studios|Amblin Entertainment|Legenda...          2015
# 4     Universal Pictures|Original Film|Media Rights ...          2015
# 14    Marvel Studios|Prime Focus|Revolution Sun Studios          2015
# 3374  Warner Bros.|Heyday Films|Moving Picture Compa...          2011
# 5422  Walt Disney Pictures|Walt Disney Animation Stu...          2013
# 5425                                     Marvel Studios          2013
# 8         Universal Pictures|Illumination Entertainment          2015
# 3522  Paramount Pictures|Di Bonaventura Pictures|Has...          2011
# 4949                      WingNut Films|New Line Cinema          2003
# 4365                                  Columbia Pictures          2012
# 8094                                  Columbia Pictures          1995
# 4363  Legendary Pictures|Warner Bros.|DC Entertainme...          2012
# 6555  Walt Disney Pictures|Jerry Bruckheimer Films|S...          2006
# 1930       Walt Disney Pictures|Pixar Animation Studios          2010
# 1921  Walt Disney Pictures|Team Todd|Tim Burton Prod...          2010
# 3375  Walt Disney Pictures|Jerry Bruckheimer Films|M...          2011
# 4367  WingNut Films|New Line Cinema|Metro-Goldwyn-Ma...          2012
# 2875  DC Comics|Legendary Pictures|Warner Bros.|Syncopy          2008
# 2634            1492 Pictures|Warner Bros.|Heyday Films          2001
# 5434      Universal Pictures|Illumination Entertainment          2013
# 7387  Walt Disney Pictures|Jerry Bruckheimer Films|S...          2007
# 5431  WingNut Films|New Line Cinema|Metro-Goldwyn-Ma...          2013
# 634   WingNut Films|New Line Cinema|3Foot7|Metro-Gol...          2014
# 1923                          Warner Bros.|Heyday Films          2010
# 7388  Cool Music|Warner Bros.|Heyday Films|Harry Pot...          2007
# 1389                          Warner Bros.|Heyday Films          2009
#
#         budget_adj   revenue_adj
# 1386  2.408869e+08  2.827124e+09
# 3     1.839999e+08  1.902723e+09
# 5231  2.716921e+08  2.506406e+09
# 4361  2.089437e+08  1.443191e+09
# 0     1.379999e+08  1.392446e+09
# 4     1.747999e+08  1.385749e+09
# 14    2.575999e+08  1.292632e+09
# 3374  1.211748e+08  1.287184e+09
# 5422  1.404050e+08  1.192711e+09
# 5425  1.872067e+08  1.137692e+09
# 8     6.807997e+07  1.064192e+09
# 3522  1.890326e+08  1.089358e+09
# 4949  1.114231e+08  1.326278e+09
# 4365  1.899489e+08  1.052849e+09
# 8094  3.148127e+07  1.583050e+09
# 4363  2.374361e+08  1.026713e+09
# 6555  2.163338e+08  1.152691e+09
# 1930  2.000000e+08  1.063172e+09
# 1921  2.000000e+08  1.025467e+09
# 3375  3.683713e+08  9.904175e+08
# 4367  2.374361e+08  9.658933e+08
# 2875  1.873655e+08  1.014733e+09
# 2634  1.539360e+08  1.202518e+09
# 5434  7.113853e+07  9.086655e+08
# 7387  3.155006e+08  1.010654e+09
# 5431  2.340083e+08  8.970944e+08
# 634   2.302728e+08  8.797523e+08
# 1923  2.500000e+08  9.543059e+08
# 7388  1.577503e+08  9.866889e+08
# 1389  2.541001e+08  9.492765e+08

# %%
plt.subplots(figsize=(15, 10))
plt.bar(df_top30['original_title'], df_top30['revenue']);
plt.xticks(rotation=90);
plt.title('Top 30 Movies by Revenue');
plt.xlabel('Title')
plt.ylabel('Revenue')
# Out:
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# <a id="conclusions"></a>
# ## Conclusions
#
# > Using the cell below, write a brief conclusion of what you have found from the anaylsis of the data. The Cell below will allow you to write plan text instead of code.

# %% [markdown]
# Looking at the top 30 movies by revenue, one could reasonably conclude that the most profitable movies are movies in existing popular franchises with name recognition. Of the top 30, only 4 are not part of a franchise or based on a pre-existing intelectual property: Avatar, Titanic, Frozen, and The Net.
#
# Movies based on popular books and comic books also seem to do very well, as exemplified by Harry Potter, Lord of the Rings/ the Hobbit, Marvel, and Batman movies
#
# The top grossing genres are action and adventure, and the top 30 movies shows this, since the vast majority of them fall into the action or adveture categories. The third most popular genre is comedy. Looking at the top 30, it appears that the highest grossing comedies are animated childrens movies, like Minions, Toy Story 3, and Despicable Me 2.
